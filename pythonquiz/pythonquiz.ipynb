# %% [markdown]
# # Pesudocode For Python Quiz
#
# ### 1. Print some welcome msgs
# ### 2. Make a dict with questions, options, and correct answer
# ### 3. Make a loop to traverse on dict and get user input
# ### 4. Use conditionals to check the correct answer
# ### 5. Print the final score using fstring

# %%
print("😊Welcome To Python Quiz!")
print("Answer The Following Qs By Typing a, b, c")
print("GOODLUCK!😃")

questions = [
 {
    "question" : "Which is the correct keyword to define a python function?",
    "options" : {"a": "def", "b":"keyword", "c": "function"},
    "correct_answer" : "a"
},
 {

    "question" : "Which symbol is used for making comments in python?",
    "options" : {"a": "!", "b":"#", "c": "//"},
    "correct_answer" : "b"

},
 {

    "question" : "Which data type in python is used to store True/Flase?",
    "options" : {"a": "string", "b":"Boolean", "c": "Variable"},
    "correct_answer" : "b"
},
 {

    "question" : "What is meant by type casting in python?",
    "options" : {"a": "changing type of datatypes", "b":"creating datatypes", "c": "none of above"},
    "correct_answer" : "a"
},
 {
    
    "question" : "Which loops are mostly used in python?",
    "options" : {"a": "for loop", "b":"while loop", "c": "both a & b"},
    "correct_answer" : "c"
}
]

score = 0

for Q in questions:
    print(Q["question"])

    for key, value in Q["options"].items():
        print(f" {key}) {value}")

    user_answer = input("Enter Your Answer!").lower()

    if user_answer == Q["correct_answer"]:
        print("✅correct answer!")
        score +=1

    else: 
        print("❌wrong answer!")


print(f"your final score is: {score}/{len(questions)}")
# Out:
# 😊Welcome To Python Quiz!
# Answer The Following Qs By Typing a, b, c
# GOODLUCK!😃
# Which is the correct keyword to define a python function?
#  a) def
#  b) keyword
#  c) function
# ✅correct answer!
# Which symbol is used for making comments in python?
#  a) !
#  b) #
#  c) //
# ✅correct answer!
# Which data type in python is used to store True/Flase?
#  a) string
#  b) Boolean
#  c) Variable
# ✅correct answer!
# What is meant by type casting in python?
#  a) changing type of datatypes
#  b) creating datatypes
#  c) none of above
# ✅correct answer!
# Which loops are mostly used in python?
#  a) for loop
#  b) while loop
#  c) both a & b
# ❌wrong answer!
# your final score is: 4/5
