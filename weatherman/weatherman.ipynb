# %%
#step1: import random module for temps

import random

print("WELCOME TO WEATHERMAN!😊")

#step2: gererating random temps for user input

temp = int(input("Enter today's temperature(°C)"))


print("weather report:")


print(f"temperature : {temp}°C")

#step3: making weather report 

if temp >=30:
    print("Hot🥵, Dont forget to drink water🫗")
elif temp >=20:
    print("Warm🫠, Put on a nice t-shirt")
elif temp >=10:
    print("Cool🤧, Be aware of strong gushes of wind🍃")
else:
    print("Cold🥶, Wear ur gloves🧤")

print("Have a great day!🫡")
# Out:
# WELCOME TO WEATHERMAN!😊
# weather report:
# temperature : 45°C
# Hot🥵, Dont forget to drink water🫗
# Have a great day!🫡
